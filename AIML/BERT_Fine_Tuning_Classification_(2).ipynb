# %% [markdown]
# # Notes

# %% [markdown]
# ## Install and Import

# %% [markdown]
# Google Colab offers free GPUs and TPUs! Since we'll be training a large neural network it's best to take advantage of this (in this case we'll attach a GPU), otherwise training will take a very long time.
#
# A GPU can be added by going to the menu and selecting:
#
# Edit -> Notebook Settings -> Add accelerator (GPU)
#
# Then run the following cell to confirm that the GPU is detected.

# %%
import tensorflow as tf

device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
# !pip install pytorch-pretrained-bert pytorch-nlp
# Out:
# Collecting pytorch-pretrained-bert
#   Downloading pytorch_pretrained_bert-0.6.2-py3-none-any.whl.metadata (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.7/86.7 kB 3.1 MB/s eta 0:00:00
# Collecting pytorch-nlp
#   Downloading pytorch_nlp-0.5.0-py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: torch>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from pytorch-pretrained-bert) (2.6.0+cu124)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from pytorch-pretrained-bert) (2.0.2)
# Collecting boto3 (from pytorch-pretrained-bert)
#   Downloading boto3-1.40.9-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from pytorch-pretrained-bert) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from pytorch-pretrained-bert) (4.67.1)
# Requirement already satisfied: regex in /usr/local/lib/python3.11/dist-packages (from pytorch-pretrained-bert) (2024.11.6)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=0.4.1->pytorch-pretrained-bert) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=0.4.1->pytorch-pretrained-bert) (4.14.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=0.4.1->pytorch-pretrained-bert) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=0.4.1->pytorch-pretrained-bert) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=0.4.1->pytorch-pretrained-bert) (2025.3.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=0.4.1->pytorch-pretrained-bert)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=0.4.1->pytorch-pretrained-bert)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=0.4.1->pytorch-pretrained-bert)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=0.4.1->pytorch-pretrained-bert)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=0.4.1->pytorch-pretrained-bert)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=0.4.1->pytorch-pretrained-bert)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=0.4.1->pytorch-pretrained-bert)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=0.4.1->pytorch-pretrained-bert)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=0.4.1->pytorch-pretrained-bert)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=0.4.1->pytorch-pretrained-bert) (0.6.2)
# Collecting nvidia-nccl-cu12==2.21.5 (from torch>=0.4.1->pytorch-pretrained-bert)
#   Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=0.4.1->pytorch-pretrained-bert) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=0.4.1->pytorch-pretrained-bert)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=0.4.1->pytorch-pretrained-bert) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=0.4.1->pytorch-pretrained-bert) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=0.4.1->pytorch-pretrained-bert) (1.3.0)
# Collecting botocore<1.41.0,>=1.40.9 (from boto3->pytorch-pretrained-bert)
#   Downloading botocore-1.40.9-py3-none-any.whl.metadata (5.7 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3->pytorch-pretrained-bert)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.14.0,>=0.13.0 (from boto3->pytorch-pretrained-bert)
#   Downloading s3transfer-0.13.1-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->pytorch-pretrained-bert) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->pytorch-pretrained-bert) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->pytorch-pretrained-bert) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->pytorch-pretrained-bert) (2025.8.3)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.11/dist-packages (from botocore<1.41.0,>=1.40.9->boto3->pytorch-pretrained-bert) (2.9.0.post0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=0.4.1->pytorch-pretrained-bert) (3.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.41.0,>=1.40.9->boto3->pytorch-pretrained-bert) (1.17.0)
# Downloading pytorch_pretrained_bert-0.6.2-py3-none-any.whl (123 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.8/123.8 kB 6.5 MB/s eta 0:00:00
# Downloading pytorch_nlp-0.5.0-py3-none-any.whl (90 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.1/90.1 kB 5.6 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 109.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 92.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 60.5 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.2 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.0 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.5 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.2 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.6 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl (188.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 7.5 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 66.4 MB/s eta 0:00:00
# Downloading boto3-1.40.9-py3-none-any.whl (140 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.1/140.1 kB 14.0 MB/s eta 0:00:00
# Downloading botocore-1.40.9-py3-none-any.whl (14.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.0/14.0 MB 76.8 MB/s eta 0:00:00
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading s3transfer-0.13.1-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.3/85.3 kB 8.7 MB/s eta 0:00:00
# Installing collected packages: pytorch-nlp, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, jmespath, nvidia-cusparse-cu12, nvidia-cudnn-cu12, botocore, s3transfer, nvidia-cusolver-cu12, boto3, pytorch-pretrained-bert
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.23.4
#     Uninstalling nvidia-nccl-cu12-2.23.4:
#       Successfully uninstalled nvidia-nccl-cu12-2.23.4
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed boto3-1.40.9 botocore-1.40.9 jmespath-1.0.1 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nccl-cu12-2.21.5 nvidia-nvjitlink-cu12-12.4.127 pytorch-nlp-0.5.0 pytorch-pretrained-bert-0.6.2 s3transfer-0.13.1

# %%
import torch
from torch.utils.data import TensorDataset, DataLoader, RandomSampler, SequentialSampler
from keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split
from pytorch_pretrained_bert import BertTokenizer, BertConfig
from pytorch_pretrained_bert import BertAdam, BertForSequenceClassification
from tqdm import tqdm, trange
import pandas as pd
import io
import numpy as np
import matplotlib.pyplot as plt
# % matplotlib inline

# %% [markdown]
# In order for torch to use the GPU, we need to identify and specify the GPU as the device. Later, in our training loop, we will load data onto the device.

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
n_gpu = torch.cuda.device_count()
torch.cuda.get_device_name(0)
# Out:
# 'Tesla T4'

# %% [markdown]
# ### preprocessing text data

# %%
data={"label":[], "sentence":[]}
with open('train_10k.txt','r') as text:
  for l in text:
    check=l.split()
    data["label"].append(check[0][9:])

    sent=""
    for i in check[1:]:
      sent+=i+" "
    data["sentence"].append(sent)

data
# Out:
# {'label': ['Hindi',
#   'Malayalam',
#   'Sindhi',
#   'Telugu',
#   'Konkani',
#   'Punjabi',
#   'Maithili',
#   'Kashmiri',
#   'Sanskrit',
#   'Assamese',
#   'Telugu',
#   'Gujarati',
#   'Bodo',
#   'Sindhi',
#   'Sanskrit',
#   'Punjabi',
#   'Kannada',
#   'Malayalam',
#   'Kannada',
#   'English',
#   'Other',
#   'Bangla',
#   'Urdu',
#   'Gujarati',
#   'Kannada',
#   'Assamese',
#   'Sindhi',
#   'Bodo',
#   'Bangla',
#   'English',
#   'Konkani',
#   'Sanskrit',
#   'Sindhi',
#   'Other',
#   'Tamil',
#   'English',
#   'Sanskrit',
#   'Manipuri_Mei',
#   'Bangla',
#   'Marathi',
#   'English',
#   'Bangla',
#   'Kashmiri',
#   'Telugu',
#   'Bangla',
#   'Manipuri_Mei',
#   'Marathi',
#   'Konkani',
#   'Bangla',
#   'Gujarati',
#   'Tamil',
#   'Marathi',
#   'Malayalam',
#   'Bangla',
#   'Tamil',
#   'Sindhi',
#   'Punjabi',
#   'Malayalam',
#   'English',
#   'Gujarati',
#   'Punjabi',
#   'Bodo',
#   'Urdu',
#   'Bodo',
#   'Bangla',
#   'Bangla',
#   'English',
#   'Kannada',
#   'Malayalam',
#   'Sindhi',
#   'Malayalam',
#   'Bangla',
#   'Bodo',
#   'Hindi',
#   'Sindhi',
#   'Malayalam',
#   'Other',
#   'Urdu',
#   'Malayalam',
#   'Marathi',
#   'Oriya',
#   'Malayalam',
#   'Bangla',
#   'Assamese',
#   'Bangla',
#   'Malayalam',
#   'Sanskrit',
#   'Hindi',
#   'Gujarati',
#   'Kannada',
#   'Maithili',
#   'Bangla',
#   'Manipuri_Mei',
#   'Sindhi',
#   'Tamil',
#   'Bangla',
#   'Punjabi',
#   'Nepali',
#   'Hindi',
#   'Bangla',
#   'Punjabi',
#   'Sanskrit',
#   'Sindhi',
#   'Manipuri_Mei',
#   'Manipuri_Mei',
#   'Konkani',
#   'Urdu',
#   'Nepali',
#   'Sanskrit',
#   'English',
#   'Assamese',
#   'Oriya',
#   'Assamese',
#   'Marathi',
#   'Kashmiri',
#   'Assamese',
#   'Sindhi',
#   'Assamese',
#   'Oriya',
#   'Tamil',
#   'Bangla',
#   'Nepali',
#   'Nepali',
#   'Konkani',
#   'Marathi',
#   'Marathi',
#   'Kannada',
#   'Maithili',
#   'Assamese',
#   'Oriya',
#   'Urdu',
#   'Kannada',
#   'Maithili',
#   'Sindhi',
#   'English',
#   'Konkani',
#   'Bangla',
#   'Marathi',
#   'Malayalam',
#   'Hindi',
#   'English',
#   'Bodo',
#   'Nepali',
#   'English',
#   'Hindi',
#   'Manipuri_Mei',
#   'Konkani',
#   'Urdu',
#   'Assamese',
#   'Assamese',
#   'Assamese',
#   'Bangla',
#   'Urdu',
#   'Sanskrit',
#   'Tamil',
#   'Sanskrit',
#   'Oriya',
#   'Gujarati',
#   'Bangla',
#   'Gujarati',
#   'Bangla',
#   'Oriya',
#   'Nepali',
#   'Marathi',
#   'Bodo',
#   'Bodo',
#   'Hindi',
#   'Marathi',
#   'Bodo',
#   'Maithili',
#   'Hindi',
#   'Konkani',
#   'Manipuri_Mei',
#   'Gujarati',
#   'Telugu',
#   'Gujarati',
#   'Other',
#   'Assamese',
#   'English',
#   'Oriya',
#   'Kannada',
#   'Bodo',
#   'Nepali',
#   'English',
#   'Hindi',
#   'Telugu',
#   'Kashmiri',
#   'Sanskrit',
#   'Konkani',
#   'Maithili',
#   'Marathi',
#   'Urdu',
#   'Assamese',
#   'Sanskrit',
#   'Nepali',
#   'Bodo',
#   'Other',
#   'Maithili',
#   'Malayalam',
#   'Kashmiri',
#   'Kannada',
#   'Sanskrit',
#   'Punjabi',
#   'Oriya',
#   'Kannada',
#   'Manipuri_Mei',
#   'English',
#   'Bangla',
#   'Sanskrit',
#   'Sindhi',
#   'Bodo',
#   'Nepali',
#   'Assamese',
#   'Maithili',
#   'Bodo',
#   'Nepali',
#   'Malayalam',
#   'Sanskrit',
#   'Sindhi',
#   'Gujarati',
#   'Kashmiri',
#   'Punjabi',
#   'Other',
#   'Bodo',
#   'Gujarati',
#   'Bodo',
#   'Urdu',
#   'Assamese',
#   'Nepali',
#   'Nepali',
#   'Other',
#   'Assamese',
#   'Bodo',
#   'Telugu',
#   'Telugu',
#   'Tamil',
#   'Telugu',
#   'Other',
#   'Assamese',
#   'Telugu',
#   'Manipuri_Mei',
#   'English',
#   'Sindhi',
#   'Sindhi',
#   'Kashmiri',
#   'Kannada',
#   'Hindi',
#   'Bodo',
#   'Telugu',
#   'Konkani',
#   'Telugu',
#   'Konkani',
#   'Other',
#   'English',
#   'Gujarati',
#   'Sanskrit',
#   'Nepali',
#   'Bodo',
#   'Gujarati',
#   'Bangla',
#   'Malayalam',
#   'Nepali',
#   'Gujarati',
#   'Bangla',
#   'Sanskrit',
#   'Bodo',
#   'Gujarati',
#   'Tamil',
#   'Kannada',
#   'Other',
#   'Punjabi',
#   'Bodo',
#   'Nepali',
#   'Sindhi',
#   'Kashmiri',
#   'Konkani',
#   'Telugu',
#   'Bodo',
#   'Bangla',
#   'Punjabi',
#   'Kashmiri',
#   'Sanskrit',
#   'Hindi',
#   'Konkani',
#   'Marathi',
#   'Malayalam',
#   'Telugu',
#   'Nepali',
#   'Bangla',
#   'Konkani',
#   'Sindhi',
#   'Tamil',
#   'Assamese',
#   'Konkani',
#   'Malayalam',
#   'Kannada',
#   'Malayalam',
#   'Hindi',
#   'Nepali',
#   'Urdu',
#   'Bangla',
#   'English',
#   'Punjabi',
#   'Kashmiri',
#   'Assamese',
#   'Telugu',
#   'Manipuri_Mei',
#   'Other',
#   'Sanskrit',
#   'Konkani',
#   'Other',
#   'Sindhi',
#   'Manipuri_Mei',
#   'Manipuri_Mei',
#   'Assamese',
#   'Bodo',
#   'Kannada',
#   'Kannada',
#   'Punjabi',
#   'Maithili',
#   'Bodo',
#   'Assamese',
#   'Manipuri_Mei',
#   'Maithili',
#   'Malayalam',
#   'Tamil',
#   'Maithili',
#   'Bangla',
#   'Hindi',
#   'English',
#   'Nepali',
#   'Konkani',
#   'Tamil',
#   'Oriya',
#   'Gujarati',
#   'Gujarati',
#   'Kannada',
#   'Other',
#   'Gujarati',
#   'Marathi',
#   'Nepali',
#   'Manipuri_Mei',
#   'Bangla',
#   'Punjabi',
#   'Gujarati',
#   'Urdu',
#   'Sanskrit',
#   'Konkani',
#   'Gujarati',
#   'Urdu',
#   'Other',
#   'Bangla',
#   'Maithili',
#   'Bodo',
#   'Bodo',
#   'Bangla',
#   'Bangla',
#   'Tamil',
#   'Urdu',
#   'Hindi',
#   'Manipuri_Mei',
#   'English',
#   'Nepali',
#   'Punjabi',
#   'Assamese',
#   'Nepali',
#   'Kannada',
#   'Urdu',
#   'Kannada',
#   'Telugu',
#   'Urdu',
#   'Gujarati',
#   'Gujarati',
#   'Gujarati',
#   'Kannada',
#   'Manipuri_Mei',
#   'Nepali',
#   'Bangla',
#   'Other',
#   'English',
#   'Urdu',
#   'Konkani',
#   'Gujarati',
#   'English',
#   'Punjabi',
#   'Maithili',
#   'Manipuri_Mei',
#   'Konkani',
#   'Tamil',
#   'Oriya',
#   'Manipuri_Mei',
#   'Punjabi',
#   'Nepali',
#   'Sindhi',
#   'English',
#   'Punjabi',
#   'Maithili',
#   'Maithili',
#   'Sanskrit',
#   'Other',
#   'Sanskrit',
#   'Tamil',
#   'Kannada',
#   'Other',
#   'Tamil',
#   'Other',
#   'Sanskrit',
#   'Sindhi',
#   'Marathi',
#   'Sanskrit',
#   'Punjabi',
#   'Assamese',
#   'Tamil',
#   'Sanskrit',
#   'Urdu',
#   'Gujarati',
#   'Bodo',
#   'Manipuri_Mei',
#   'Bangla',
#   'Tamil',
#   'Nepali',
#   'Manipuri_Mei',
#   'Sindhi',
#   'Gujarati',
#   'English',
#   'Marathi',
#   'Bangla',
#   'Bodo',
#   'Sindhi',
#   'Assamese',
#   'Gujarati',
#   'Oriya',
#   'Manipuri_Mei',
#   'Sindhi',
#   'Kashmiri',
#   'Other',
#   'Gujarati',
#   'Kannada',
#   'Sindhi',
#   'Other',
#   'Telugu',
#   'Nepali',
#   'English',
#   'Maithili',
#   'Maithili',
#   'Hindi',
#   'Urdu',
#   'Sanskrit',
#   'Maithili',
#   'Konkani',
#   'Nepali',
#   'Bodo',
#   'Bangla',
#   'Nepali',
#   'Telugu',
#   'English',
#   'Kashmiri',
#   'Oriya',
#   'Gujarati',
#   'Marathi',
#   'Kannada',
#   'Sindhi',
#   'Urdu',
#   'Malayalam',
#   'Assamese',
#   'English',
#   'Kashmiri',
#   'Konkani',
#   'Malayalam',
#   'English',
#   'Konkani',
#   'Urdu',
#   'English',
#   'Manipuri_Mei',
#   'Malayalam',
#   'Gujarati',
#   'Other',
#   'Other',
#   'Hindi',
#   'English',
#   'Nepali',
#   'Punjabi',
#   'Telugu',
#   'Konkani',
#   'Telugu',
#   'Kannada',
#   'Manipuri_Mei',
#   'Sanskrit',
#   'Gujarati',
#   'Punjabi',
#   'Nepali',
#   'Telugu',
#   'Urdu',
#   'Manipuri_Mei',
#   'Punjabi',
#   'Punjabi',
#   'Bodo',
#   'Marathi',
#   'Hindi',
#   'Manipuri_Mei',
#   'Urdu',
#   'Nepali',
#   'Sanskrit',
#   'Hindi',
#   'Kannada',
#   'Hindi',
#   'Sindhi',
#   'Hindi',
#   'Nepali',
#   'Oriya',
#   'Hindi',
#   'Bodo',
#   'Kashmiri',
#   'Kannada',
#   'Bangla',
#   'Punjabi',
#   'Telugu',
#   'Telugu',
#   'English',
#   'English',
#   'Sindhi',
#   'Urdu',
#   'Bodo',
#   'Tamil',
#   'Urdu',
#   'Nepali',
#   'Punjabi',
#   'Tamil',
#   'Bangla',
#   'Bangla',
#   'English',
#   'Hindi',
#   'Sindhi',
#   'Other',
#   'Urdu',
#   'Sanskrit',
#   'Punjabi',
#   'Hindi',
#   'Malayalam',
#   'Bangla',
#   'Telugu',
#   'Telugu',
#   'Malayalam',
#   'Gujarati',
#   'Urdu',
#   'Assamese',
#   'English',
#   'Other',
#   'Telugu',
#   'Nepali',
#   'Malayalam',
#   'Urdu',
#   'Kannada',
#   'Marathi',
#   'Oriya',
#   'Punjabi',
#   'Bodo',
#   'Manipuri_Mei',
#   'Tamil',
#   'English',
#   'Marathi',
#   'Sindhi',
#   'Other',
#   'Nepali',
#   'Kashmiri',
#   'Malayalam',
#   'Telugu',
#   'Maithili',
#   'Bangla',
#   'Manipuri_Mei',
#   'Sanskrit',
#   'Manipuri_Mei',
#   'Sindhi',
#   'English',
#   'Urdu',
#   'Other',
#   'Other',
#   'Tamil',
#   'Gujarati',
#   'Nepali',
#   'Bodo',
#   'Kashmiri',
#   'Bangla',
#   'Kashmiri',
#   'Assamese',
#   'Kannada',
#   'Oriya',
#   'Malayalam',
#   'Kannada',
#   'Sindhi',
#   'Punjabi',
#   'English',
#   'Marathi',
#   'Tamil',
#   'Konkani',
#   'Punjabi',
#   'Sanskrit',
#   'Punjabi',
#   'Telugu',
#   'Sindhi',
#   'Manipuri_Mei',
#   'Other',
#   'Bodo',
#   'Nepali',
#   'Malayalam',
#   'Kashmiri',
#   'Sanskrit',
#   'Kannada',
#   'Sindhi',
#   'Kannada',
#   'Sanskrit',
#   'Sanskrit',
#   'Urdu',
#   'Kannada',
#   'Assamese',
#   'Gujarati',
#   'Bangla',
#   'English',
#   'Konkani',
#   'Maithili',
#   'Oriya',
#   'Bodo',
#   'Sindhi',
#   'Punjabi',
#   'Sindhi',
#   'Oriya',
#   'Urdu',
#   'Urdu',
#   'Telugu',
#   'Marathi',
#   'English',
#   'Maithili',
#   'Bangla',
#   'Manipuri_Mei',
#   'Punjabi',
#   'Urdu',
#   'Oriya',
#   'Assamese',
#   'Urdu',
#   'Sindhi',
#   'Nepali',
#   'Bodo',
#   'Manipuri_Mei',
#   'Malayalam',
#   'Other',
#   'Tamil',
#   'Nepali',
#   'Kashmiri',
#   'Kashmiri',
#   'Gujarati',
#   'Bodo',
#   'Punjabi',
#   'Marathi',
#   'English',
#   'Bangla',
#   'Bangla',
#   'Kashmiri',
#   'Bangla',
#   'Kashmiri',
#   'Bangla',
#   'Marathi',
#   'Urdu',
#   'Kashmiri',
#   'Kannada',
#   'Maithili',
#   'Bodo',
#   'Nepali',
#   'Sindhi',
#   'Bodo',
#   'Manipuri_Mei',
#   'Hindi',
#   'Konkani',
#   'Bodo',
#   'Assamese',
#   'Nepali',
#   'English',
#   'Nepali',
#   'Bangla',
#   'Gujarati',
#   'Hindi',
#   'Sindhi',
#   'Assamese',
#   'Manipuri_Mei',
#   'Malayalam',
#   'Tamil',
#   'Manipuri_Mei',
#   'Kannada',
#   'Sindhi',
#   'Manipuri_Mei',
#   'Nepali',
#   'Telugu',
#   'Urdu',
#   'Kannada',
#   'Manipuri_Mei',
#   'Punjabi',
#   'Tamil',
#   'Other',
#   'Oriya',
#   'Oriya',
#   'Konkani',
#   'Punjabi',
#   'Bodo',
#   'Sanskrit',
#   'Malayalam',
#   'Punjabi',
#   'Bodo',
#   'Kashmiri',
#   'English',
#   'Kannada',
#   'Telugu',
#   'Oriya',
#   'Hindi',
#   'Telugu',
#   'Sindhi',
#   'Kashmiri',
#   'Bodo',
#   'Konkani',
#   'Punjabi',
#   'Gujarati',
#   'Other',
#   'Sanskrit',
#   'Sanskrit',
#   'Kannada',
#   'Nepali',
#   'Sindhi',
#   'Marathi',
#   'Sanskrit',
#   'Hindi',
#   'Nepali',
#   'Sindhi',
#   'Manipuri_Mei',
#   'Tamil',
#   'Bodo',
#   'Maithili',
#   'Assamese',
#   'Kashmiri',
#   'Bangla',
#   'Kashmiri',
#   'Tamil',
#   'Bodo',
#   'Malayalam',
#   'Sanskrit',
#   'Malayalam',
#   'Sindhi',
#   'Assamese',
#   'Other',
#   'Urdu',
#   'Marathi',
#   'Telugu',
#   'Malayalam',
#   'Tamil',
#   'Other',
#   'Bodo',
#   'Telugu',
#   'Bangla',
#   'English',
#   'Assamese',
#   'Bodo',
#   'English',
#   'Hindi',
#   'Kashmiri',
#   'Telugu',
#   'Kannada',
#   'Telugu',
#   'Bodo',
#   'Hindi',
#   'Bangla',
#   'Bodo',
#   'Bodo',
#   'Bodo',
#   'Marathi',
#   'Other',
#   'Kannada',
#   'Konkani',
#   'Gujarati',
#   'Malayalam',
#   'Bodo',
#   'Bangla',
#   'Urdu',
#   'Bodo',
#   'Kashmiri',
#   'Tamil',
#   'Tamil',
#   'Telugu',
#   'Other',
#   'Tamil',
#   'Nepali',
#   'Manipuri_Mei',
#   'Oriya',
#   'Malayalam',
#   'Maithili',
#   'Sanskrit',
#   'Marathi',
#   'Maithili',
#   'Maithili',
#   'Hindi',
#   'Urdu',
#   'Tamil',
#   'Kashmiri',
#   'Sanskrit',
#   'Tamil',
#   'Sanskrit',
#   'Kannada',
#   'Sanskrit',
#   'Sindhi',
#   'Oriya',
#   'Sanskrit',
#   'Tamil',
#   'Malayalam',
#   'Kashmiri',
#   'Sindhi',
#   'Urdu',
#   'Manipuri_Mei',
#   'Maithili',
#   'Malayalam',
#   'Marathi',
#   'Nepali',
#   'Other',
#   'Marathi',
#   'Sindhi',
#   'Gujarati',
#   'Tamil',
#   'Oriya',
#   'Sindhi',
#   'Malayalam',
#   'Bangla',
#   'Kannada',
#   'Urdu',
#   'Oriya',
#   'Bodo',
#   'Hindi',
#   'Punjabi',
#   'Marathi',
#   'Maithili',
#   'Maithili',
#   'Kannada',
#   'Gujarati',
#   'Konkani',
#   'Konkani',
#   'Kashmiri',
#   'Punjabi',
#   'Assamese',
#   'Telugu',
#   'Telugu',
#   'Konkani',
#   'Malayalam',
#   'Oriya',
#   'Manipuri_Mei',
#   'Kashmiri',
#   'Telugu',
#   'Tamil',
#   'Malayalam',
#   'Manipuri_Mei',
#   'English',
#   'Tamil',
#   'Kashmiri',
#   'Bodo',
#   'Assamese',
#   'Oriya',
#   'Oriya',
#   'Gujarati',
#   'Other',
#   'Punjabi',
#   'Tamil',
#   'Other',
#   'English',
#   'Other',
#   'Sindhi',
#   'Sindhi',
#   'Sindhi',
#   'Other',
#   'Maithili',
#   'Hindi',
#   'Telugu',
#   'Telugu',
#   'Other',
#   'Nepali',
#   'Tamil',
#   'Nepali',
#   'Bodo',
#   'Konkani',
#   'Telugu',
#   'English',
#   'Marathi',
#   'Konkani',
#   'Punjabi',
#   'Maithili',
#   'Manipuri_Mei',
#   'Marathi',
#   'Kannada',
#   'Gujarati',
#   'Assamese',
#   'Telugu',
#   'Oriya',
#   'Assamese',
#   'Manipuri_Mei',
#   'Hindi',
#   'Oriya',
#   'Punjabi',
#   'Konkani',
#   'Sindhi',
#   'Punjabi',
#   'Sanskrit',
#   'Gujarati',
#   'Telugu',
#   'Sindhi',
#   'Marathi',
#   'Other',
#   'Tamil',
#   'Gujarati',
#   'Konkani',
#   'Telugu',
#   'Sindhi',
#   'Konkani',
#   'Maithili',
#   'Other',
#   'Maithili',
#   'Other',
#   'Malayalam',
#   'Bangla',
#   'Konkani',
#   'Nepali',
#   'Kannada',
#   'Kashmiri',
#   'Urdu',
#   'Konkani',
#   'Marathi',
#   'Kashmiri',
#   'Tamil',
#   'Assamese',
#   'Kashmiri',
#   'Kashmiri',
#   'Tamil',
#   'Hindi',
#   'Hindi',
#   'Sanskrit',
#   'Marathi',
#   'Telugu',
#   'Gujarati',
#   'Bodo',
#   'Kannada',
#   'English',
#   'Maithili',
#   'Konkani',
#   'Malayalam',
#   'Punjabi',
#   'Punjabi',
#   'English',
#   'Telugu',
#   'Urdu',
#   'Nepali',
#   'Bodo',
#   'Sanskrit',
#   'Nepali',
#   'Urdu',
#   'Punjabi',
#   'Bodo',
#   'Sanskrit',
#   'Punjabi',
#   'Punjabi',
#   'English',
#   'Maithili',
#   'Other',
#   'Other',
#   'Urdu',
#   'Other',
#   'Konkani',
#   'Kannada',
#   'English',
#   'Manipuri_Mei',
#   'Telugu',
#   'Gujarati',
#   'Other',
#   'Kashmiri',
#   'Other',
#   'Telugu',
#   'Tamil',
#   'Kashmiri',
#   'Oriya',
#   'Urdu',
#   'Maithili',
#   'Punjabi',
#   'Maithili',
#   'Assamese',
#   'Kashmiri',
#   'Bangla',
#   'Kashmiri',
#   'Gujarati',
#   'Marathi',
#   'Kannada',
#   'Sindhi',
#   'Bangla',
#   'Marathi',
#   'Sanskrit',
#   'Bangla',
#   'Manipuri_Mei',
#   'Bangla',
#   'Hindi',
#   'Oriya',
#   'Tamil',
#   ...],
#  'sentence': ['aisee bachat hamein una sthitiyon mein bhee sahaayata karati haye , jaba humm kamai karane mein saksham naheen hotey hain , udaaharan key liye sevaanivritti key baad . ',
#   'kramanugathamaayi eee alavu kootti 15 varsham ( praayapoortthi ) aakumbol oro maratthinum 50 kiloo pachila / compoost / jaiva valangalil eathenkilum onnum 500:250:100 gram kanakkil raasavalavum nalkanam . ',
#   'mislan : musjid nabvi jee qareeb hikk board tee likhyal dithham : ',
#   'haikortu nambaru prakaram : ',
#   'samajik samatayechyo baryoch ghoshana karoon legeet hyaa deshant nigro khaatir jaay tashe hakk hanga naat . ',
#   "jailh jaanh vaale jatthe noon ravana kardiaan sree panoon neey kiha kii \\ ' jailh bharo \\ ' andolan lagatar jaari rahega atey aaunde kujh dinan takk bibiaan dey jatthe vee jailh bharo andolan witch shamal qarr ditte jaange . ",
#   'geet merae khaga baal ! ',
#   "R I hom ' sund hemak sund hom ' sɨnd ' hemak sende hum ' sɨnz huim senz ",
#   'yathaa sankhyabhyupagatani panchavimshatitattvaani , eteshaamatiriktatwen ekaha eeshwarah astiti eeshwaratatwamapi patanjalirayam sweekaroti ityatah asya naam seshvaravaadee saankhyah iti . ',
#   "pahare - porbote - bhoiyame pepati bojale oxomiya jaati - upojatir xokolure monn rongiyal hoh ' boloi dhore . ",
#   'andulo algay ( aakupacchani , neelam ranguvi ) binduvullaagaa vuntaayi . ',
#   'utpaadan karvaanu hoya tevee vastunu qada , vajan , rung , ghaat vagere nakki karvaa maate viveedh technologyno upyog karvaamaa aave chhe . ',
#   'mumbai , february 18 : mungdangka boliudni hatorki , faokunggur okshoi kumar bitangah tangnai brihosiptibarkali jommu arw kashmir hadwrsani pulwama jillayao pakistan hadwrao jwnwm mwnnai jais - ee - mohamod udkari hanjani gaglwbnayao bhartini rwoniya hanjani crpf dwlwni saa 40 nibw bangsin swdrwmapwrni mungklong jalangnaikwo jwbwd dukumwnnai fwrmayw . ',
#   'behtar munafin laae pola panhenjo safar jaaree rakhandi saraee puhta, jatee sonhri lashkar jee takhat nasheen barkee khaan jee darbaar waqia huee . ',
#   'aagneyabhaagasy kollegaalasya shailaah etasya vaayoh avarodham kurvanti iti karanena atra sikataraashih sanchitah asti . ',
#   'hunn jagg lae jaao , berry dolh dio , adrak , mirch , dalchini , mirch atey mutter majburi vodka naal sutto . ',
#   'neevu kuduremukha nodilwa miss ',
#   'keey ezz krishnan ( 1898 dism 4 - 1961 juun 13 ) ',
#   'nantara aatitheyara aata innashtu rangeritu . ',
#   'The case had taken a turn after the arrest of Prakash Thampi by the Directorate of Revenue Intelligence ( DRI ) in a gold smuggling case . ',
#   'sameer oo chandrakanta taake pulisher sahayatai uddhar korey . ',
#   'iss mulyankan key baad , unesco dwara site koo " viraasat seey parey bethanie ( all - magtas ) " sheershak key tahat vishva viraasat sthal key roop mein ankit kiya gayaa thaa . ',
#   'internet ( warldwide web ) kimba intranet ( gharoi network ) paain website bikashita karuthiba pesadara byaktinku web developer kuhajae . ',
#   '15 . awahanati mutthirai : sannirodhinee : kattaiviralgal ullae maraiya , mattra naanku viralgalin nagangkal ondrukkondru urasa , muttikalaich saerththup pidiththal . ',
#   ...]}

# %%
df=pd.DataFrame(data)

# %%
df.head()
# Out:
#        label                                           sentence
# 0      Hindi  aisee bachat hamein una sthitiyon mein bhee sa...
# 1  Malayalam  kramanugathamaayi eee alavu kootti 15 varsham ...
# 2     Sindhi  mislan : musjid nabvi jee qareeb hikk board te...
# 3     Telugu                       haikortu nambaru prakaram :
# 4    Konkani  samajik samatayechyo baryoch ghoshana karoon l...

# %%
df.shape
# Out:
# (10000, 2)

# %%
df.sample(10)
# Out:
#          label                                           sentence
# 265       Bodo  be rajkanti dwlwni swmwndwi bwhwiti danni 31 k...
# 5256   Konkani                                  jaivant sardesai
# 3983     Tamil  idhu thavirntha aenaiya abiviruththi seyarpaad...
# 2916   Konkani  hem rojaar tey shetkaar aangavonechyo chuttam ...
# 5599  Sanskrit  mahaarouravaraajashcha sthaanam teshaam nibodh...
# 7034     Oriya  ehipari shukra taralyaru dhwajabhangabhali bha...
# 1525  Sanskrit  bahadurakhan poorvam burhanpuradurgasya prabha...
# 1457   Marathi  yaa cinematil aanakhi eka vyaktirekha samore a...
# 795      Hindi  baad mein , iss avadharana koo jameen millie a...
# 1743   Punjabi  tii dee vaccine 2 bimariaan toon bachaa karda ...

# %%
# Create sentence and label lists
sentences = df.sentence.values

# We need to add special tokens at the beginning and end of each sentence for BERT to work properly
sentences = ["[CLS] " + sentence + " [SEP]" for sentence in sentences]
labels = df.label.values
sentences[:10]
# Out:
# ['[CLS] aisee bachat hamein una sthitiyon mein bhee sahaayata karati haye , jaba humm kamai karane mein saksham naheen hotey hain , udaaharan key liye sevaanivritti key baad .  [SEP]',
#  '[CLS] kramanugathamaayi eee alavu kootti 15 varsham ( praayapoortthi ) aakumbol oro maratthinum 50 kiloo pachila / compoost / jaiva valangalil eathenkilum onnum 500:250:100 gram kanakkil raasavalavum nalkanam .  [SEP]',
#  '[CLS] mislan : musjid nabvi jee qareeb hikk board tee likhyal dithham :  [SEP]',
#  '[CLS] haikortu nambaru prakaram :  [SEP]',
#  '[CLS] samajik samatayechyo baryoch ghoshana karoon legeet hyaa deshant nigro khaatir jaay tashe hakk hanga naat .  [SEP]',
#  "[CLS] jailh jaanh vaale jatthe noon ravana kardiaan sree panoon neey kiha kii \\ ' jailh bharo \\ ' andolan lagatar jaari rahega atey aaunde kujh dinan takk bibiaan dey jatthe vee jailh bharo andolan witch shamal qarr ditte jaange .  [SEP]",
#  '[CLS] geet merae khaga baal !  [SEP]',
#  "[CLS] R I hom ' sund hemak sund hom ' sɨnd ' hemak sende hum ' sɨnz huim senz  [SEP]",
#  '[CLS] yathaa sankhyabhyupagatani panchavimshatitattvaani , eteshaamatiriktatwen ekaha eeshwarah astiti eeshwaratatwamapi patanjalirayam sweekaroti ityatah asya naam seshvaravaadee saankhyah iti .  [SEP]',
#  "[CLS] pahare - porbote - bhoiyame pepati bojale oxomiya jaati - upojatir xokolure monn rongiyal hoh ' boloi dhore .  [SEP]"]

# %% [markdown]
# ## Inputs

# %% [markdown]
# Next, import the BERT tokenizer, used to convert our text into tokens that correspond to BERT's vocabulary.

# %%
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased', do_lower_case=True)

tokenized_texts = [tokenizer.tokenize(sent) for sent in sentences]
print ("Tokenize the first sentence:")
print (tokenized_texts[0])
# Out:
# Tokenize the first sentence:
# ['[CLS]', 'ai', '##see', 'bach', '##at', 'ham', '##ein', 'una', 'st', '##hiti', '##yon', 'mein', 'b', '##hee', 'sa', '##ha', '##aya', '##ta', 'kara', '##ti', 'hay', '##e', ',', 'ja', '##ba', 'hum', '##m', 'kam', '##ai', 'kara', '##ne', 'mein', 'sa', '##ksha', '##m', 'nah', '##een', 'hot', '##ey', 'hai', '##n', ',', 'ud', '##aa', '##hara', '##n', 'key', 'li', '##ye', 'se', '##va', '##ani', '##vr', '##itt', '##i', 'key', 'ba', '##ad', '.', '[SEP]']

# %% [markdown]
# BERT requires specifically formatted inputs. For each tokenized input sentence, we need to create:
#
# - **input ids**: a sequence of integers identifying each input token to its index number in the BERT tokenizer vocabulary
# - **segment mask**: (optional) a sequence of 1s and 0s used to identify whether the input is one sentence or two sentences long. For one sentence inputs, this is simply a sequence of 0s. For two sentence inputs, there is a 0 for each token of the first sentence, followed by a 1 for each token of the second sentence
# - **attention mask**: (optional) a sequence of 1s and 0s, with 1s for all input tokens and 0s for all padding tokens (we'll detail this in the next paragraph)
# - **labels**: a single value of 1 or 0. In our task 1 means "grammatical" and 0 means "ungrammatical"

# %% [markdown]
# Although we can have variable length input sentences, BERT does requires our input arrays to be the same size. We address this by first choosing a maximum sentence length, and then padding and truncating our inputs until every input sequence is of the same length.
#
# To "pad" our inputs in this context means that if a sentence is shorter than the maximum sentence length, we simply add 0s to the end of the sequence until it is the maximum sentence length.
#
# If a sentence is longer than the maximum sentence length, then we simply truncate the end of the sequence, discarding anything that does not fit into our maximum sentence length.
#
# We pad and truncate our sequences so that they all become of length MAX_LEN ("post" indicates that we want to pad and truncate at the end of the sequence, as opposed to the beginning) `pad_sequences` is a utility function that we're borrowing from Keras. It simply handles the truncating and padding of Python lists.

# %%
# Set the maximum sequence length. The longest sequence in our training set is 47, but we'll leave room on the end anyway.
# In the original paper, the authors used a length of 512.
MAX_LEN = 128

# %%
# Pad our input tokens
input_ids = pad_sequences([tokenizer.convert_tokens_to_ids(txt) for txt in tokenized_texts],
                          maxlen=MAX_LEN, dtype="long", truncating="post", padding="post")
# Out:
# WARNING:pytorch_pretrained_bert.tokenization:Token indices sequence length is longer than the specified maximum  sequence length for this BERT model (897 > 512). Running this sequence through BERT will result in indexing errors
# WARNING:pytorch_pretrained_bert.tokenization:Token indices sequence length is longer than the specified maximum  sequence length for this BERT model (879 > 512). Running this sequence through BERT will result in indexing errors
# WARNING:pytorch_pretrained_bert.tokenization:Token indices sequence length is longer than the specified maximum  sequence length for this BERT model (875 > 512). Running this sequence through BERT will result in indexing errors
# WARNING:pytorch_pretrained_bert.tokenization:Token indices sequence length is longer than the specified maximum  sequence length for this BERT model (686 > 512). Running this sequence through BERT will result in indexing errors
# WARNING:pytorch_pretrained_bert.tokenization:Token indices sequence length is longer than the specified maximum  sequence length for this BERT model (527 > 512). Running this sequence through BERT will result in indexing errors
# WARNING:pytorch_pretrained_bert.tokenization:Token indices sequence length is longer than the specified maximum  sequence length for this BERT model (754 > 512). Running this sequence through BERT will result in indexing errors
# WARNING:pytorch_pretrained_bert.tokenization:Token indices sequence length is longer than the specified maximum  sequence length for this BERT model (535 > 512). Running this sequence through BERT will result in indexing errors
# WARNING:pytorch_pretrained_bert.tokenization:Token indices sequence length is longer than the specified maximum  sequence length for this BERT model (1350 > 512). Running this sequence through BERT will result in indexing errors
# WARNING:pytorch_pretrained_bert.tokenization:Token indices sequence length is longer than the specified maximum  sequence length for this BERT model (896 > 512). Running this sequence through BERT will result in indexing errors
# WARNING:pytorch_pretrained_bert.tokenization:Token indices sequence length is longer than the specified maximum  sequence length for this BERT model (1275 > 512). Running this sequence through BERT will result in indexing errors
# WARNING:pytorch_pretrained_bert.tokenization:Token indices sequence length is longer than the specified maximum  sequence length for this BERT model (600 > 512). Running this sequence through BERT will result in indexing errors
# WARNING:pytorch_pretrained_bert.tokenization:Token indices sequence length is longer than the specified maximum  sequence length for this BERT model (586 > 512). Running this sequence through BERT will result in indexing errors
# WARNING:pytorch_pretrained_bert.tokenization:Token indices sequence length is longer than the specified maximum  sequence length for this BERT model (592 > 512). Running this sequence through BERT will result in indexing errors
# WARNING:pytorch_pretrained_bert.tokenization:Token indices sequence length is longer than the specified maximum  sequence length for this BERT model (529 > 512). Running this sequence through BERT will result in indexing errors
# WARNING:pytorch_pretrained_bert.tokenization:Token indices sequence length is longer than the specified maximum  sequence length for this BERT model (524 > 512). Running this sequence through BERT will result in indexing errors
# WARNING:pytorch_pretrained_bert.tokenization:Token indices sequence length is longer than the specified maximum  sequence length for this BERT model (1514 > 512). Running this sequence through BERT will result in indexing errors
# WARNING:pytorch_pretrained_bert.tokenization:Token indices sequence length is longer than the specified maximum  sequence length for this BERT model (848 > 512). Running this sequence through BERT will result in indexing errors
# WARNING:pytorch_pretrained_bert.tokenization:Token indices sequence length is longer than the specified maximum  sequence length for this BERT model (529 > 512). Running this sequence through BERT will result in indexing errors
# WARNING:pytorch_pretrained_bert.tokenization:Token indices sequence length is longer than the specified maximum  sequence length for this BERT model (787 > 512). Running this sequence through BERT will result in indexing errors
# WARNING:pytorch_pretrained_bert.tokenization:Token indices sequence length is longer than the specified maximum  sequence length for this BERT model (591 > 512). Running this sequence through BERT will result in indexing errors

# %%
# Use the BERT tokenizer to convert the tokens to their index numbers in the BERT vocabulary
input_ids = [tokenizer.convert_tokens_to_ids(x) for x in tokenized_texts]
# Out:
# WARNING:pytorch_pretrained_bert.tokenization:Token indices sequence length is longer than the specified maximum  sequence length for this BERT model (897 > 512). Running this sequence through BERT will result in indexing errors
# WARNING:pytorch_pretrained_bert.tokenization:Token indices sequence length is longer than the specified maximum  sequence length for this BERT model (879 > 512). Running this sequence through BERT will result in indexing errors
# WARNING:pytorch_pretrained_bert.tokenization:Token indices sequence length is longer than the specified maximum  sequence length for this BERT model (875 > 512). Running this sequence through BERT will result in indexing errors
# WARNING:pytorch_pretrained_bert.tokenization:Token indices sequence length is longer than the specified maximum  sequence length for this BERT model (686 > 512). Running this sequence through BERT will result in indexing errors
# WARNING:pytorch_pretrained_bert.tokenization:Token indices sequence length is longer than the specified maximum  sequence length for this BERT model (527 > 512). Running this sequence through BERT will result in indexing errors
# WARNING:pytorch_pretrained_bert.tokenization:Token indices sequence length is longer than the specified maximum  sequence length for this BERT model (754 > 512). Running this sequence through BERT will result in indexing errors
# WARNING:pytorch_pretrained_bert.tokenization:Token indices sequence length is longer than the specified maximum  sequence length for this BERT model (535 > 512). Running this sequence through BERT will result in indexing errors
# WARNING:pytorch_pretrained_bert.tokenization:Token indices sequence length is longer than the specified maximum  sequence length for this BERT model (1350 > 512). Running this sequence through BERT will result in indexing errors
# WARNING:pytorch_pretrained_bert.tokenization:Token indices sequence length is longer than the specified maximum  sequence length for this BERT model (896 > 512). Running this sequence through BERT will result in indexing errors
# WARNING:pytorch_pretrained_bert.tokenization:Token indices sequence length is longer than the specified maximum  sequence length for this BERT model (1275 > 512). Running this sequence through BERT will result in indexing errors
# WARNING:pytorch_pretrained_bert.tokenization:Token indices sequence length is longer than the specified maximum  sequence length for this BERT model (600 > 512). Running this sequence through BERT will result in indexing errors
# WARNING:pytorch_pretrained_bert.tokenization:Token indices sequence length is longer than the specified maximum  sequence length for this BERT model (586 > 512). Running this sequence through BERT will result in indexing errors
# WARNING:pytorch_pretrained_bert.tokenization:Token indices sequence length is longer than the specified maximum  sequence length for this BERT model (592 > 512). Running this sequence through BERT will result in indexing errors
# WARNING:pytorch_pretrained_bert.tokenization:Token indices sequence length is longer than the specified maximum  sequence length for this BERT model (529 > 512). Running this sequence through BERT will result in indexing errors
# WARNING:pytorch_pretrained_bert.tokenization:Token indices sequence length is longer than the specified maximum  sequence length for this BERT model (524 > 512). Running this sequence through BERT will result in indexing errors
# WARNING:pytorch_pretrained_bert.tokenization:Token indices sequence length is longer than the specified maximum  sequence length for this BERT model (1514 > 512). Running this sequence through BERT will result in indexing errors
# WARNING:pytorch_pretrained_bert.tokenization:Token indices sequence length is longer than the specified maximum  sequence length for this BERT model (848 > 512). Running this sequence through BERT will result in indexing errors
# WARNING:pytorch_pretrained_bert.tokenization:Token indices sequence length is longer than the specified maximum  sequence length for this BERT model (529 > 512). Running this sequence through BERT will result in indexing errors
# WARNING:pytorch_pretrained_bert.tokenization:Token indices sequence length is longer than the specified maximum  sequence length for this BERT model (787 > 512). Running this sequence through BERT will result in indexing errors
# WARNING:pytorch_pretrained_bert.tokenization:Token indices sequence length is longer than the specified maximum  sequence length for this BERT model (591 > 512). Running this sequence through BERT will result in indexing errors

# %%
input_ids = pad_sequences(input_ids, maxlen=MAX_LEN, dtype="long", truncating="post", padding="post")

# %%
len(input_ids)
# Out:
# 10000

# %% [markdown]
# Create the attention masks

# %%
# Create attention masks
attention_masks = []

# Create a mask of 1s for each token followed by 0s for padding
for seq in input_ids:
  seq_mask = [float(i>0) for i in seq]
  attention_masks.append(seq_mask)

# %%
# Use train_test_split to split our data into train and validation sets for training

train_inputs, validation_inputs, train_labels, validation_labels = train_test_split(input_ids, labels,
                                                            random_state=2018, test_size=0.1)
train_masks, validation_masks, _, _ = train_test_split(attention_masks, input_ids,
                                             random_state=2018, test_size=0.1)

# %%
print("training labels",np.unique(train_labels))
np.unique(validation_labels)
# Out:
# training labels ['Assamese' 'Bangla' 'Bodo' 'English' 'Gujarati' 'Hindi' 'Kannada'
#  'Kashmiri' 'Konkani' 'Maithili' 'Malayalam' 'Manipuri_Mei' 'Marathi'
#  'Nepali' 'Oriya' 'Other' 'Punjabi' 'Sanskrit' 'Sindhi' 'Tamil' 'Telugu'
#  'Urdu']
# array(['Assamese', 'Bangla', 'Bodo', 'English', 'Gujarati', 'Hindi',
#        'Kannada', 'Kashmiri', 'Konkani', 'Maithili', 'Malayalam',
#        'Manipuri_Mei', 'Marathi', 'Nepali', 'Oriya', 'Other', 'Punjabi',
#        'Sanskrit', 'Sindhi', 'Tamil', 'Telugu', 'Urdu'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
train_labels = label_encoder.fit_transform(train_labels)
validation_labels = label_encoder.transform(validation_labels)

# %%
# Convert all of our data into torch tensors, the required datatype for our model

train_inputs = torch.tensor(train_inputs)
validation_inputs = torch.tensor(validation_inputs)
train_labels = torch.tensor(train_labels)
validation_labels = torch.tensor(validation_labels)
train_masks = torch.tensor(train_masks)
validation_masks = torch.tensor(validation_masks)

# %%
# Select a batch size for training. For fine-tuning BERT on a specific task, the authors recommend a batch size of 16 or 32
batch_size = 16

# Create an iterator of our data with torch DataLoader. This helps save on memory during training because, unlike a for loop,
# with an iterator the entire dataset does not need to be loaded into memory

train_data = TensorDataset(train_inputs, train_masks, train_labels)
train_sampler = RandomSampler(train_data)
train_dataloader = DataLoader(train_data, sampler=train_sampler, batch_size=batch_size)

validation_data = TensorDataset(validation_inputs, validation_masks, validation_labels)
validation_sampler = SequentialSampler(validation_data)
validation_dataloader = DataLoader(validation_data, sampler=validation_sampler, batch_size=batch_size)

# %% [markdown]
# ## Train Model

# %% [markdown]
# Now that our input data is properly formatted, it's time to fine tune the BERT model.
#
# For this task, we first want to modify the pre-trained BERT model to give outputs for classification, and then we want to continue training the model on our dataset until that the entire model, end-to-end, is well-suited for our task. Thankfully, the huggingface pytorch implementation includes a set of interfaces designed for a variety of NLP tasks. Though these interfaces are all built on top of a trained BERT model, each has different top layers and output types designed to accomodate their specific NLP task.
#
# We'll load [BertForSequenceClassification](https://github.com/huggingface/pytorch-pretrained-BERT/blob/master/pytorch_pretrained_bert/modeling.py#L1129). This is the normal BERT model with an added single linear layer on top for classification that we will use as a sentence classifier. As we feed input data, the entire pre-trained BERT model and the additional untrained classification layer is trained on our specific task.
#
# ### Structure of Fine-Tuning Model
#
# As we've showed beforehand, the first token of every sequence is the special classification token ([CLS]). Unlike the hidden state vector corresponding to a normal word token, the hidden state corresponding to this special token is designated by the authors of BERT as an aggregate representation of the whole sentence used for classification tasks. As such, when we feed in an input sentence to our model during training, the output is the length 768 hidden state vector corresponding to this token. The additional layer that we've added on top consists of untrained linear neurons of size [hidden_state, number_of_labels], so [768,2], meaning that the output of BERT plus our classification layer is a vector of two numbers representing the "score" for "grammatical/non-grammatical" that are then fed into cross-entropy loss.
#
# <img src='https://encrypted-tbn2.gstatic.com/images?q=tbn:ANd9GcR-hV5tsDFdanx37pw9jzx3_Br30T2RnwsEJUhcsT-R_ugjdh3YVJuJNe1_e2l8nhYpVO9O'>
#
# ### The Fine-Tuning Process
#
# Because the pre-trained BERT layers already encode a lot of information about the language, training the classifier is relatively inexpensive. Rather than training every layer in a large model from scratch, it's as if we have already trained the bottom layers 95% of where they need to be, and only really need to train the top layer, with a bit of tweaking going on in the lower levels to accomodate our task.
#
# Sometimes practicioners will opt to "freeze" certain layers when fine-tuning, or to apply different learning rates, apply diminishing learning rates, etc. all in an effort to preserve the good quality weights in the network and speed up training (often considerably). In fact, recent research on BERT specifically has demonstrated that freezing the majority of the weights results in only minimal accuracy declines, but there are exceptions and broader rules of transfer learning that should also be considered. For example, if your task and fine-tuning dataset is very different from the dataset used to train the transfer learning model, freezing the weights may not be a good idea. We'll cover the broader scope of transfer learning in NLP in a future post.

# %% [markdown]
# OK, let's load BERT! There are a few different pre-trained BERT models available. "bert-base-uncased" means the version that has only lowercase letters ("uncased") and is the smaller version of the two ("base" vs "large").

# %%
# Load BertForSequenceClassification, the pretrained BERT model with a single linear classification layer on top.

model = BertForSequenceClassification.from_pretrained("bert-base-uncased", num_labels=22)
model.cuda()
# Out:
# BertForSequenceClassification(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): BertLayerNorm()
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): BertLayerNorm()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (classifier): Linear(in_features=768, out_features=22, bias=True)
# )

# %% [markdown]
# Now that we have our model loaded we need to grab the training hyperparameters from within the stored model.
#
# For the purposes of fine-tuning, the authors recommend the following hyperparameter ranges:
# - Batch size: 16, 32
# - Learning rate (Adam): 5e-5, 3e-5, 2e-5
# - Number of epochs: 2, 3, 4

# %%
param_optimizer = list(model.named_parameters())
no_decay = ['bias', 'gamma', 'beta']
optimizer_grouped_parameters = [
    {'params': [p for n, p in param_optimizer if not any(nd in n for nd in no_decay)],
     'weight_decay_rate': 0.01},
    {'params': [p for n, p in param_optimizer if any(nd in n for nd in no_decay)],
     'weight_decay_rate': 0.0}
]

# %%
# This variable contains all of the hyperparemeter information our training loop needs
optimizer = BertAdam(optimizer_grouped_parameters,
                     lr=2e-5,
                     warmup=.1)
# Out:
# WARNING:pytorch_pretrained_bert.optimization:t_total value of -1 results in schedule not being applied

# %% [markdown]
# Below is our training loop. There's a lot going on, but fundamentally for each pass in our loop we have a trianing phase and a validation phase. At each pass we need to:
#
# Training loop:
# - Tell the model to compute gradients by setting the model in train mode
# - Unpack our data inputs and labels
# - Load data onto the GPU for acceleration
# - Clear out the gradients calculated in the previous pass. In pytorch the gradients accumulate by default (useful for things like RNNs) unless you explicitly clear them out
# - Forward pass (feed input data through the network)
# - Backward pass (backpropagation)
# - Tell the network to update parameters with optimizer.step()
# - Track variables for monitoring progress
#
# Evalution loop:
# - Tell the model not to compute gradients by setting th emodel in evaluation mode
# - Unpack our data inputs and labels
# - Load data onto the GPU for acceleration
# - Forward pass (feed input data through the network)
# - Compute loss on our validation data and track variables for monitoring progress
#
# So please read carefully through the comments to get an understanding of what's happening. If you're unfamiliar with pytorch a quick look at some of their [beginner tutorials](https://pytorch.org/tutorials/beginner/blitz/cifar10_tutorial.html#sphx-glr-beginner-blitz-cifar10-tutorial-py) will help show you that training loops really involve only a few simple steps; the rest is usually just decoration and logging.

# %%
# Function to calculate the accuracy of our predictions vs labels
def flat_accuracy(preds, labels):
    pred_flat = np.argmax(preds, axis=1).flatten()
    labels_flat = labels.flatten()
    return np.sum(pred_flat == labels_flat) / len(labels_flat)

# %%
# Store our loss and accuracy for plotting
train_loss_set = []

# Number of training epochs (authors recommend between 2 and 4)
epochs = 4

# trange is a tqdm wrapper around the normal python range
for _ in trange(epochs, desc="Epoch"):


  # Training

  # Set our model to training mode (as opposed to evaluation mode)
  model.train()

  # Tracking variables
  tr_loss = 0
  nb_tr_examples, nb_tr_steps = 0, 0

  # Train the data for one epoch
  for step, batch in enumerate(train_dataloader):
    # Add batch to GPU
    batch = tuple(t.to(device) for t in batch)
    # Unpack the inputs from our dataloader
    b_input_ids, b_input_mask, b_labels = batch
    # Clear out the gradients (by default they accumulate)
    optimizer.zero_grad()
    # Forward pass
    loss = model(b_input_ids, token_type_ids=None, attention_mask=b_input_mask, labels=b_labels)
    train_loss_set.append(loss.item())
    # Backward pass
    loss.backward()
    # Update parameters and take a step using the computed gradient
    optimizer.step()


    # Update tracking variables
    tr_loss += loss.item()
    nb_tr_examples += b_input_ids.size(0)
    nb_tr_steps += 1

  print("Train loss: {}".format(tr_loss/nb_tr_steps))


  # Validation

  # Put model in evaluation mode to evaluate loss on the validation set
  model.eval()

  # Tracking variables
  eval_loss, eval_accuracy = 0, 0
  nb_eval_steps, nb_eval_examples = 0, 0

  # Evaluate data for one epoch
  for batch in validation_dataloader:
    # Add batch to GPU
    batch = tuple(t.to(device) for t in batch)
    # Unpack the inputs from our dataloader
    b_input_ids, b_input_mask, b_labels = batch
    # Telling the model not to compute or store gradients, saving memory and speeding up validation
    with torch.no_grad():
      # Forward pass, calculate logit predictions
      logits = model(b_input_ids, token_type_ids=None, attention_mask=b_input_mask)

    # Move logits and labels to CPU
    logits = logits.detach().cpu().numpy()
    label_ids = b_labels.to('cpu').numpy()

    tmp_eval_accuracy = flat_accuracy(logits, label_ids)

    eval_accuracy += tmp_eval_accuracy
    nb_eval_steps += 1

  print("Validation Accuracy: {}".format(eval_accuracy/nb_eval_steps))
# Out:
# Epoch:   0%|          | 0/4 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/pytorch_pretrained_bert/optimization.py:275: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add_(Tensor other, *, Number alpha = 1) (Triggered internally at /pytorch/torch/csrc/utils/python_arg_parser.cpp:1661.)
#   next_m.mul_(beta1).add_(1 - beta1, grad)
# Train loss: 1.2786281339122814
# Epoch:  25%|██▌       | 1/4 [04:18<12:54, 258.23s/it]
# Validation Accuracy: 0.8174603174603174
# Train loss: 0.3605839352670984
# Epoch:  50%|█████     | 2/4 [08:38<08:38, 259.33s/it]
# Validation Accuracy: 0.8849206349206349
# Train loss: 0.13931039823665817
# Epoch:  75%|███████▌  | 3/4 [12:51<04:16, 256.48s/it]
# Validation Accuracy: 0.8918650793650794
# Train loss: 0.06063668179568929
# Epoch: 100%|██████████| 4/4 [17:04<00:00, 256.03s/it]
# Validation Accuracy: 0.8918650793650794

# %%
torch.cuda.empty_cache()

# %%
# !kill -9 -1

# %%
# !nvidia-smi
# Out:
# Thu Aug 14 14:29:24 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   65C    P0             29W /   70W |     574MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# ## Training Evaluation

# %% [markdown]
# Let's take a look at our training loss over all batches:

# %%
plt.figure(figsize=(15,8))
plt.title("Training loss")
plt.xlabel("Batch")
plt.ylabel("Loss")
plt.plot(train_loss_set)
plt.show()

# %% [markdown]
# ##Predict and Evaluate on Holdout Set

# %% [markdown]
# Now we'll load the holdout dataset and prepare inputs just as we did with the training set. Then we'll evaluate predictions using [Matthew's correlation coefficient](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.matthews_corrcoef.html) because this is the metric used by the wider NLP community to evaluate performance on CoLA. With this metric, +1 is the best score, and -1 is the worst score. This way, we can see how well we perform against the state of the art models for this specific task.

# %%
#using the same code using to preprocess the val data from evaluation
data_val={"label":[], "sentence":[]}
with open('val_1k.txt','r') as text:
  for l in text:
    check=l.split()
    data_val["label"].append(check[0][9:])

    sent=""
    for i in check[1:]:
      sent+=i+" "
    data_val["sentence"].append(sent)

data_val
# Out:
# {'label': ['Kashmiri',
#   'Assamese',
#   'Oriya',
#   'Sanskrit',
#   'Punjabi',
#   'Kannada',
#   'Bangla',
#   'Other',
#   'Maithili',
#   'Hindi',
#   'Other',
#   'Telugu',
#   'Gujarati',
#   'Telugu',
#   'Malayalam',
#   'Nepali',
#   'Nepali',
#   'Malayalam',
#   'Tamil',
#   'Sindhi',
#   'Marathi',
#   'Manipuri_Mei',
#   'Manipuri_Mei',
#   'Punjabi',
#   'Assamese',
#   'Sanskrit',
#   'Urdu',
#   'English',
#   'English',
#   'Telugu',
#   'Bangla',
#   'Punjabi',
#   'Marathi',
#   'Tamil',
#   'Hindi',
#   'Telugu',
#   'Kannada',
#   'Gujarati',
#   'Gujarati',
#   'Oriya',
#   'Other',
#   'Assamese',
#   'Sindhi',
#   'Maithili',
#   'Telugu',
#   'Assamese',
#   'Maithili',
#   'Other',
#   'Hindi',
#   'Nepali',
#   'Punjabi',
#   'Kannada',
#   'Nepali',
#   'Manipuri_Mei',
#   'Gujarati',
#   'Telugu',
#   'Punjabi',
#   'Assamese',
#   'Oriya',
#   'Sindhi',
#   'Kannada',
#   'Nepali',
#   'Tamil',
#   'Assamese',
#   'Telugu',
#   'Kashmiri',
#   'Marathi',
#   'Gujarati',
#   'Gujarati',
#   'Punjabi',
#   'Sanskrit',
#   'Punjabi',
#   'Kannada',
#   'Sindhi',
#   'Urdu',
#   'Telugu',
#   'Marathi',
#   'Other',
#   'Kannada',
#   'Manipuri_Mei',
#   'Assamese',
#   'Other',
#   'English',
#   'Konkani',
#   'Sanskrit',
#   'Other',
#   'Sanskrit',
#   'Maithili',
#   'Other',
#   'Other',
#   'Manipuri_Mei',
#   'Bodo',
#   'Hindi',
#   'Urdu',
#   'Punjabi',
#   'Sanskrit',
#   'Kannada',
#   'Sindhi',
#   'Malayalam',
#   'Hindi',
#   'Bodo',
#   'Malayalam',
#   'Sindhi',
#   'Telugu',
#   'Other',
#   'Hindi',
#   'Sindhi',
#   'Hindi',
#   'Punjabi',
#   'Konkani',
#   'Kashmiri',
#   'Kashmiri',
#   'Kannada',
#   'Kashmiri',
#   'Konkani',
#   'Malayalam',
#   'Tamil',
#   'Assamese',
#   'Marathi',
#   'Tamil',
#   'Other',
#   'Sindhi',
#   'Nepali',
#   'Maithili',
#   'Bodo',
#   'Malayalam',
#   'Tamil',
#   'Sanskrit',
#   'Assamese',
#   'Sindhi',
#   'Urdu',
#   'Kannada',
#   'Punjabi',
#   'Telugu',
#   'Assamese',
#   'Sanskrit',
#   'Tamil',
#   'Malayalam',
#   'Malayalam',
#   'Maithili',
#   'Manipuri_Mei',
#   'Punjabi',
#   'Assamese',
#   'Bangla',
#   'Sanskrit',
#   'Hindi',
#   'Nepali',
#   'Konkani',
#   'Marathi',
#   'Gujarati',
#   'Punjabi',
#   'English',
#   'Malayalam',
#   'Tamil',
#   'Konkani',
#   'Hindi',
#   'Marathi',
#   'Sanskrit',
#   'Urdu',
#   'Gujarati',
#   'Marathi',
#   'Malayalam',
#   'Bodo',
#   'Kashmiri',
#   'English',
#   'Bodo',
#   'Marathi',
#   'Sanskrit',
#   'Maithili',
#   'Assamese',
#   'Sanskrit',
#   'Assamese',
#   'Kashmiri',
#   'Maithili',
#   'Konkani',
#   'Gujarati',
#   'Nepali',
#   'Tamil',
#   'Malayalam',
#   'Tamil',
#   'Sanskrit',
#   'Oriya',
#   'Sindhi',
#   'English',
#   'Other',
#   'Konkani',
#   'Sanskrit',
#   'Oriya',
#   'Other',
#   'Hindi',
#   'Punjabi',
#   'Tamil',
#   'Kannada',
#   'Telugu',
#   'Oriya',
#   'Oriya',
#   'Bodo',
#   'Oriya',
#   'Konkani',
#   'Kannada',
#   'Sanskrit',
#   'Urdu',
#   'Marathi',
#   'Punjabi',
#   'Telugu',
#   'Nepali',
#   'Punjabi',
#   'Manipuri_Mei',
#   'Sindhi',
#   'Bodo',
#   'Hindi',
#   'Manipuri_Mei',
#   'Other',
#   'Hindi',
#   'Nepali',
#   'Telugu',
#   'Tamil',
#   'Other',
#   'Other',
#   'English',
#   'Konkani',
#   'Konkani',
#   'Telugu',
#   'Marathi',
#   'Punjabi',
#   'Gujarati',
#   'Assamese',
#   'Kannada',
#   'Kashmiri',
#   'Tamil',
#   'Assamese',
#   'Malayalam',
#   'Manipuri_Mei',
#   'Kannada',
#   'Kannada',
#   'Manipuri_Mei',
#   'Hindi',
#   'Punjabi',
#   'Bodo',
#   'Tamil',
#   'Telugu',
#   'Telugu',
#   'Nepali',
#   'Punjabi',
#   'Konkani',
#   'Bangla',
#   'Punjabi',
#   'Maithili',
#   'Gujarati',
#   'Sanskrit',
#   'Kashmiri',
#   'Assamese',
#   'English',
#   'Tamil',
#   'Other',
#   'Sindhi',
#   'English',
#   'Gujarati',
#   'Gujarati',
#   'Punjabi',
#   'Konkani',
#   'Bodo',
#   'Bangla',
#   'Sindhi',
#   'English',
#   'Assamese',
#   'Oriya',
#   'Gujarati',
#   'Nepali',
#   'Urdu',
#   'Punjabi',
#   'Manipuri_Mei',
#   'Malayalam',
#   'Assamese',
#   'Sindhi',
#   'Malayalam',
#   'Hindi',
#   'Maithili',
#   'Kashmiri',
#   'Maithili',
#   'Malayalam',
#   'Telugu',
#   'Telugu',
#   'Bangla',
#   'English',
#   'Nepali',
#   'Kashmiri',
#   'Marathi',
#   'Nepali',
#   'Bangla',
#   'Kashmiri',
#   'Urdu',
#   'Kashmiri',
#   'Gujarati',
#   'English',
#   'Sanskrit',
#   'Konkani',
#   'Telugu',
#   'Marathi',
#   'Manipuri_Mei',
#   'Telugu',
#   'Kannada',
#   'Hindi',
#   'Hindi',
#   'English',
#   'Konkani',
#   'Gujarati',
#   'Telugu',
#   'Hindi',
#   'Nepali',
#   'Maithili',
#   'Urdu',
#   'Bangla',
#   'English',
#   'Hindi',
#   'Assamese',
#   'Bangla',
#   'Manipuri_Mei',
#   'Marathi',
#   'Nepali',
#   'Bangla',
#   'Bangla',
#   'Tamil',
#   'English',
#   'Bodo',
#   'Bodo',
#   'Bangla',
#   'Tamil',
#   'Sanskrit',
#   'Konkani',
#   'English',
#   'Sindhi',
#   'Marathi',
#   'English',
#   'Bangla',
#   'Kashmiri',
#   'Punjabi',
#   'Hindi',
#   'Gujarati',
#   'Bangla',
#   'Marathi',
#   'Urdu',
#   'Kashmiri',
#   'Manipuri_Mei',
#   'Sanskrit',
#   'English',
#   'Gujarati',
#   'Bangla',
#   'Kannada',
#   'Bodo',
#   'Manipuri_Mei',
#   'Hindi',
#   'Konkani',
#   'Marathi',
#   'Konkani',
#   'Assamese',
#   'English',
#   'Assamese',
#   'Sanskrit',
#   'Telugu',
#   'Hindi',
#   'Oriya',
#   'Oriya',
#   'Sanskrit',
#   'Punjabi',
#   'Gujarati',
#   'Manipuri_Mei',
#   'Punjabi',
#   'Sanskrit',
#   'Other',
#   'Telugu',
#   'Telugu',
#   'Bodo',
#   'Manipuri_Mei',
#   'Konkani',
#   'Malayalam',
#   'Oriya',
#   'English',
#   'Sindhi',
#   'Bodo',
#   'Konkani',
#   'Kashmiri',
#   'Sindhi',
#   'Tamil',
#   'Kashmiri',
#   'Sindhi',
#   'Sindhi',
#   'Hindi',
#   'Assamese',
#   'Oriya',
#   'Telugu',
#   'Manipuri_Mei',
#   'Oriya',
#   'Assamese',
#   'Maithili',
#   'Bodo',
#   'Maithili',
#   'English',
#   'Marathi',
#   'English',
#   'Oriya',
#   'Bodo',
#   'Sanskrit',
#   'Manipuri_Mei',
#   'English',
#   'Urdu',
#   'Gujarati',
#   'Hindi',
#   'Other',
#   'Sindhi',
#   'Sindhi',
#   'Kashmiri',
#   'Nepali',
#   'Kannada',
#   'Sanskrit',
#   'Malayalam',
#   'Sanskrit',
#   'Manipuri_Mei',
#   'English',
#   'English',
#   'Urdu',
#   'Konkani',
#   'English',
#   'Oriya',
#   'Gujarati',
#   'Maithili',
#   'Nepali',
#   'Kannada',
#   'Sanskrit',
#   'Kannada',
#   'Other',
#   'Tamil',
#   'Sanskrit',
#   'Sindhi',
#   'Manipuri_Mei',
#   'Telugu',
#   'Assamese',
#   'Tamil',
#   'Marathi',
#   'Bodo',
#   'Other',
#   'Kannada',
#   'Gujarati',
#   'Marathi',
#   'Other',
#   'Gujarati',
#   'Kashmiri',
#   'Tamil',
#   'Tamil',
#   'Oriya',
#   'Bangla',
#   'Manipuri_Mei',
#   'Kashmiri',
#   'Assamese',
#   'English',
#   'Nepali',
#   'Assamese',
#   'Assamese',
#   'Oriya',
#   'Sanskrit',
#   'Malayalam',
#   'Konkani',
#   'Oriya',
#   'Kashmiri',
#   'Hindi',
#   'Manipuri_Mei',
#   'Other',
#   'Kashmiri',
#   'Kannada',
#   'Marathi',
#   'Urdu',
#   'Kannada',
#   'Urdu',
#   'English',
#   'Punjabi',
#   'Sanskrit',
#   'English',
#   'Telugu',
#   'Nepali',
#   'Gujarati',
#   'Gujarati',
#   'Bodo',
#   'Other',
#   'Marathi',
#   'Nepali',
#   'Maithili',
#   'Maithili',
#   'Malayalam',
#   'Bodo',
#   'Punjabi',
#   'Kannada',
#   'Kannada',
#   'Kashmiri',
#   'Kannada',
#   'Maithili',
#   'Sanskrit',
#   'Other',
#   'Oriya',
#   'Assamese',
#   'Konkani',
#   'Maithili',
#   'Maithili',
#   'Sanskrit',
#   'Bangla',
#   'Telugu',
#   'Assamese',
#   'Nepali',
#   'Kannada',
#   'Tamil',
#   'Nepali',
#   'English',
#   'Nepali',
#   'Nepali',
#   'Hindi',
#   'Konkani',
#   'Kashmiri',
#   'Nepali',
#   'Gujarati',
#   'Kannada',
#   'English',
#   'Sanskrit',
#   'Urdu',
#   'Assamese',
#   'Other',
#   'Konkani',
#   'Oriya',
#   'Tamil',
#   'Telugu',
#   'Konkani',
#   'Manipuri_Mei',
#   'Sindhi',
#   'Gujarati',
#   'Kannada',
#   'Telugu',
#   'Assamese',
#   'Malayalam',
#   'Assamese',
#   'Konkani',
#   'Telugu',
#   'Marathi',
#   'Tamil',
#   'Sanskrit',
#   'Oriya',
#   'Marathi',
#   'Sindhi',
#   'Hindi',
#   'Oriya',
#   'Urdu',
#   'Bangla',
#   'English',
#   'Punjabi',
#   'Hindi',
#   'Punjabi',
#   'Hindi',
#   'Sindhi',
#   'Other',
#   'Telugu',
#   'Kannada',
#   'Urdu',
#   'Assamese',
#   'Kannada',
#   'Sanskrit',
#   'Kannada',
#   'Marathi',
#   'Gujarati',
#   'Kannada',
#   'Kashmiri',
#   'Marathi',
#   'Marathi',
#   'Nepali',
#   'Kashmiri',
#   'Maithili',
#   'Sindhi',
#   'Hindi',
#   'Nepali',
#   'Urdu',
#   'Kashmiri',
#   'Malayalam',
#   'Gujarati',
#   'Sanskrit',
#   'Hindi',
#   'Konkani',
#   'Marathi',
#   'English',
#   'Bodo',
#   'Marathi',
#   'Bangla',
#   'Bodo',
#   'Manipuri_Mei',
#   'Bangla',
#   'Konkani',
#   'Marathi',
#   'English',
#   'Manipuri_Mei',
#   'Marathi',
#   'Bangla',
#   'Malayalam',
#   'Gujarati',
#   'Punjabi',
#   'Punjabi',
#   'Tamil',
#   'Sanskrit',
#   'Oriya',
#   'Konkani',
#   'Manipuri_Mei',
#   'Gujarati',
#   'Urdu',
#   'Assamese',
#   'Sindhi',
#   'Konkani',
#   'Bangla',
#   'Bangla',
#   'Oriya',
#   'Maithili',
#   'Nepali',
#   'English',
#   'Sanskrit',
#   'Assamese',
#   'Kannada',
#   'Other',
#   'Assamese',
#   'Sindhi',
#   'Tamil',
#   'Sindhi',
#   'Sanskrit',
#   'Gujarati',
#   'Gujarati',
#   'Konkani',
#   'Bangla',
#   'Gujarati',
#   'Manipuri_Mei',
#   'Tamil',
#   'Hindi',
#   'Tamil',
#   'Gujarati',
#   'Oriya',
#   'Marathi',
#   'Manipuri_Mei',
#   'Other',
#   'Assamese',
#   'Sanskrit',
#   'Other',
#   'Urdu',
#   'Oriya',
#   'Malayalam',
#   'Malayalam',
#   'Gujarati',
#   'Bodo',
#   'Telugu',
#   'Manipuri_Mei',
#   'Hindi',
#   'Konkani',
#   'Nepali',
#   'Oriya',
#   'Konkani',
#   'Manipuri_Mei',
#   'Tamil',
#   'Nepali',
#   'Punjabi',
#   'Gujarati',
#   'Kannada',
#   'Tamil',
#   'Marathi',
#   'Malayalam',
#   'Sindhi',
#   'Telugu',
#   'Gujarati',
#   'Kashmiri',
#   'Punjabi',
#   'Nepali',
#   'Kashmiri',
#   'English',
#   'English',
#   'Telugu',
#   'Punjabi',
#   'Oriya',
#   'Punjabi',
#   'Punjabi',
#   'Tamil',
#   'Hindi',
#   'Konkani',
#   'Tamil',
#   'Bodo',
#   'Maithili',
#   'Kannada',
#   'English',
#   'Manipuri_Mei',
#   'Sanskrit',
#   'Maithili',
#   'Oriya',
#   'Maithili',
#   'Tamil',
#   'Bangla',
#   'Manipuri_Mei',
#   'Bodo',
#   'Oriya',
#   'Nepali',
#   'Telugu',
#   'Telugu',
#   'Bodo',
#   'Other',
#   'Nepali',
#   'Sanskrit',
#   'Urdu',
#   'Gujarati',
#   'Urdu',
#   'Malayalam',
#   'Hindi',
#   'Punjabi',
#   'Kashmiri',
#   'Nepali',
#   'Punjabi',
#   'Sindhi',
#   'Hindi',
#   'Hindi',
#   'Hindi',
#   'Kannada',
#   'Malayalam',
#   'Bodo',
#   'English',
#   'Bangla',
#   'Malayalam',
#   'Nepali',
#   'Manipuri_Mei',
#   'Oriya',
#   'Tamil',
#   'Maithili',
#   'Kannada',
#   'Gujarati',
#   'Konkani',
#   'Telugu',
#   'Telugu',
#   'Telugu',
#   'Maithili',
#   'Tamil',
#   'Sanskrit',
#   'Sanskrit',
#   'Tamil',
#   'Tamil',
#   'Kannada',
#   'Bodo',
#   'Nepali',
#   'Konkani',
#   'Bangla',
#   'Tamil',
#   'Konkani',
#   'Konkani',
#   'Manipuri_Mei',
#   'Nepali',
#   'Sindhi',
#   'Sindhi',
#   'Sanskrit',
#   'Sanskrit',
#   'Gujarati',
#   'Maithili',
#   'Tamil',
#   'Punjabi',
#   'Punjabi',
#   'Kannada',
#   'English',
#   'Kashmiri',
#   'Malayalam',
#   'Other',
#   'Kannada',
#   'Malayalam',
#   'Sanskrit',
#   'Gujarati',
#   'Other',
#   'Sindhi',
#   'Bangla',
#   'Assamese',
#   'Bangla',
#   'Konkani',
#   'Assamese',
#   'Telugu',
#   'Marathi',
#   'Other',
#   'Bodo',
#   'Kannada',
#   'Gujarati',
#   'Maithili',
#   'Other',
#   'Bangla',
#   'Sanskrit',
#   'Bodo',
#   'Assamese',
#   'Bodo',
#   'Gujarati',
#   'Konkani',
#   'Marathi',
#   'English',
#   'Sindhi',
#   'Maithili',
#   'Telugu',
#   'Urdu',
#   'Kannada',
#   'Gujarati',
#   'Kannada',
#   'Konkani',
#   'Marathi',
#   'Punjabi',
#   'Bangla',
#   'Oriya',
#   'Gujarati',
#   'Sindhi',
#   'Gujarati',
#   'Telugu',
#   'Other',
#   'English',
#   'Nepali',
#   'English',
#   'Konkani',
#   'Kannada',
#   'Bodo',
#   'Assamese',
#   'Sindhi',
#   'Tamil',
#   'Other',
#   'Oriya',
#   'Bodo',
#   'Oriya',
#   'Manipuri_Mei',
#   'Kannada',
#   'Kannada',
#   'Kannada',
#   'Gujarati',
#   'Telugu',
#   'Maithili',
#   'Nepali',
#   'English',
#   'Urdu',
#   'Sanskrit',
#   'Sindhi',
#   'Telugu',
#   'English',
#   'Kannada',
#   'Bangla',
#   'Telugu',
#   'Hindi',
#   'Marathi',
#   'Manipuri_Mei',
#   'Malayalam',
#   'Telugu',
#   'Gujarati',
#   'Punjabi',
#   'Manipuri_Mei',
#   'Kannada',
#   'Kannada',
#   'Maithili',
#   'Punjabi',
#   'Kannada',
#   'Bangla',
#   'Oriya',
#   'Marathi',
#   'Bodo',
#   'Marathi',
#   'Manipuri_Mei',
#   'Sindhi',
#   'Oriya',
#   'Tamil',
#   'Bangla',
#   'Manipuri_Mei',
#   'Punjabi',
#   'Malayalam',
#   'Tamil',
#   'Tamil',
#   'Bangla',
#   'Manipuri_Mei',
#   'Hindi',
#   'Bodo',
#   'Urdu',
#   'Kannada',
#   'Manipuri_Mei',
#   'Sindhi',
#   'Maithili',
#   'Gujarati',
#   'Marathi',
#   'Nepali',
#   'Kashmiri',
#   'Kannada',
#   'Telugu',
#   'Bangla',
#   'Manipuri_Mei',
#   'Bangla',
#   'Konkani',
#   'Oriya',
#   'Urdu',
#   'Bangla',
#   'English',
#   'Marathi',
#   'Oriya',
#   'Gujarati',
#   'Urdu',
#   'Kashmiri',
#   'Assamese',
#   'English',
#   'English',
#   'Konkani',
#   'Bangla',
#   'Urdu',
#   'Bangla',
#   'Konkani',
#   'Marathi',
#   'Gujarati',
#   'Sanskrit',
#   'Punjabi',
#   'Sanskrit',
#   'Maithili',
#   'Gujarati',
#   'Telugu',
#   'Sanskrit',
#   'Malayalam',
#   'Manipuri_Mei',
#   'Oriya',
#   'Marathi',
#   'Konkani',
#   'Nepali',
#   'Gujarati',
#   'Marathi',
#   'Maithili',
#   'English',
#   'Kannada',
#   'Oriya',
#   'Tamil',
#   'English',
#   'Urdu',
#   'Kashmiri',
#   'Manipuri_Mei',
#   'Tamil',
#   'Sanskrit',
#   'Bodo',
#   'Urdu',
#   'Hindi',
#   'Punjabi',
#   'Bodo',
#   'Maithili',
#   'Telugu',
#   'Marathi',
#   'Kannada',
#   'Punjabi',
#   'Manipuri_Mei',
#   'Punjabi',
#   'Bodo',
#   'Tamil',
#   'Bangla',
#   'Sindhi',
#   'Gujarati',
#   'Manipuri_Mei',
#   'Hindi',
#   'Urdu',
#   'Nepali',
#   'Other',
#   'Assamese',
#   'Punjabi',
#   'Assamese',
#   'Tamil',
#   'Manipuri_Mei',
#   'Bangla',
#   'Kannada',
#   'Bodo',
#   'Telugu',
#   'Tamil',
#   'Marathi',
#   'Other',
#   'Oriya',
#   'English',
#   'Gujarati',
#   'Bangla',
#   'Punjabi',
#   'Sindhi',
#   'Gujarati',
#   'Urdu',
#   'Kashmiri',
#   'Manipuri_Mei',
#   'English',
#   'Marathi',
#   'Sanskrit',
#   'Manipuri_Mei',
#   'Maithili',
#   'Malayalam',
#   'Nepali',
#   'Oriya',
#   'Konkani',
#   'Tamil',
#   'Manipuri_Mei',
#   'Assamese',
#   'Bangla',
#   'Telugu',
#   'Konkani',
#   'Tamil',
#   'Tamil',
#   'Gujarati',
#   'Nepali',
#   'Punjabi',
#   'Bangla',
#   'Tamil',
#   'Sanskrit',
#   'Oriya',
#   'Nepali',
#   'Tamil'],
#  'sentence': ['kaafi , das eshariya chhe faisad ',
#   'uttor guwahatih mohanogorit sakorir prolubhonere nibonuwar poraa dhon xongroho koraa hyprophile probonchok ojit daxok uttor guwahati arokhyiye obhijan solai aatok koriboloi xokhyom hoy . ',
#   'ehaa anaswikarjya je , kaunasi eka anshare jadi balaprayoga karajae tebe tahar pratiphalana kendrare nischaya prakash paiba . ',
#   'asya nagarasya samskrutihi samruddhaa asti . ',
#   'Punjab di lok naat paramparaa te panjaabi naatak – Dr. Rawel Singh ',
#   "Pramukha gruhabalakeya vastugala vibhaagavannu whirlpool kaarporeshanhge maaraata maadida balika idu 'Philips whirlpool' mattu ' whirlpool Philips' moolaka 'whirlpool' ge badalaayitu. ",
#   'nadiyar maharaja srishchondro roy ebong murshidabad jelar kasimbazarer maharani swarnomoyi colleger jonne shotadhik bigha jomi daan korle sthaniyo shikhahitoishi baktiborger arthik sohojogitay 1856 chrishtabde ekti prasadogomo bhavan nirmito hoy ja adhuna krishnonagar sarkari college name khaato. ',
#   'Non abbiamo ancora avuto risposta dal governo . ',
#   'phir kaise hoteen naa loka maen poojita . ',
#   'Parivarik kalah ke karan Narayan Laal ne apni patni Vichitra Devi evm donon putron - Murlidhar v Kalyanmal sahit apna Paitruk gaon chhod diya. ',
#   'Ho ricevuto una valanga di messaggi di solidarietà , soprattutto dagli uomini , resto convinta di essere sulla strada giusta per fare la giornalista , è il mio sogno . ',
#   'taja vyaktigata vivaralu ',
#   'India Private Limited namni company dharave chhe. ',
#   'gyaas leakage parisara gramallo vishavayu prabhavam teevrata inca tagga ledani sthaanikulu chebutunnarani annaru . ',
#   'yettavum koopduthal thavana Rail Budget avatharipichathu Jagajeevan Ram aanu (yezhu thavana). ',
#   'asiako swatantra niyaman garne sansthale nishpaksha nirvachan hune sambhawana nikai kamjor raheko bataeko chha . ',
#   'mausam , fulharu rar umrine bhinna - bhinnai paristhitiko lamo chaudo jaanch pachhi programlai jati sakdo uti , asali jasto banaune prayas gariyo . ',
#   'suvarnakshetrathil chorayozhukkiya , sikh samooha vishwaasathe murivelppicha , eee sambhavathinte 30 - aamm vaarshika dinamaaya innale nadanna chadanginidayilaanu prasnangalkku thudakkam . ',
#   '( ii ) ( auuu ) mavatta aatchiyar anaivarum . ',
#   'Hin 21 September 1959eesvi te gothh Allah-Rakhie Swhag, Taluke aen Zilley Dadu me janam warto. ',
#   'matecha aar etch raktagat vegala asalyas matechya raktatil pratidravya arbhakachya raktamadhye aparetun pravesh karate . ',
#   'boxoniyo wikipedia ',
#   'bartomane, purbo timur purbo asio deshgulor jot asiane jog dite aagrohi. ',
#   'tamilanadulo aksharaasyata 1981 loe 54.4 % vadda undagaa , 2001 loe 73.4 % niki perigindi . ',
#   'hey yevajane khaala padvyuttar padvi / padvika / pramanpatra panvdya vayale abhyaskramay aaspaavit aasat . ',
#   'Keisenin irandu mukkiya amsangal pinvaruvana aagum: ',
#   'sanga kaalatthukkup piragu , thamizhagaththil piraamanar kudiyaettramum avarkalukku vaethangkalai karpikkum kalamum thoantriyathu . ',
#   'seetaai ',
#   'yasale garda pariwartanka lagi dabawa dina gahro parchha . ',
#   '1941–Bharat de filam nirmata, patkatha lekhak ate film nirdeshak adur gopalkrishan da janam. ',
#   'bharte pray 18 hazar kilometres bistrito samudratata royeche jaa mulat machh dhorar kaaje byabohrito hoy . ',
#   'inapperukkam . ',
#   'satsangatihi janaanaam asaadhyaani karyani api saadhayati . ',
#   'ethire 170 lokankara zeeban jaichhi . ',
#   'key key chhan attis tayari kaksha haruka bisheshta . ',
#   'ingu Sivalingam oru suyambu maragadhalingam. ']}

# %%
df = pd.DataFrame(data_val)

# Create sentence and label lists
sentences = df.sentence.values

# We need to add special tokens at the beginning and end of each sentence for BERT to work properly
sentences = ["[CLS] " + sentence + " [SEP]" for sentence in sentences]
labels = df.label.values

tokenized_texts = [tokenizer.tokenize(sent) for sent in sentences]


MAX_LEN = 128
# Pad our input tokens
input_ids = pad_sequences([tokenizer.convert_tokens_to_ids(txt) for txt in tokenized_texts],
                          maxlen=MAX_LEN, dtype="long", truncating="post", padding="post")
# Use the BERT tokenizer to convert the tokens to their index numbers in the BERT vocabulary
input_ids = [tokenizer.convert_tokens_to_ids(x) for x in tokenized_texts]
input_ids = pad_sequences(input_ids, maxlen=MAX_LEN, dtype="long", truncating="post", padding="post")
# Create attention masks
attention_masks = []

# Create a mask of 1s for each token followed by 0s for padding
for seq in input_ids:
  seq_mask = [float(i>0) for i in seq]
  attention_masks.append(seq_mask)

prediction_inputs = torch.tensor(input_ids)
prediction_masks = torch.tensor(attention_masks)
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
labels = label_encoder.fit_transform(labels)

prediction_labels = torch.tensor(labels)

batch_size = 16


prediction_data = TensorDataset(prediction_inputs, prediction_masks, prediction_labels)
prediction_sampler = SequentialSampler(prediction_data)
prediction_dataloader = DataLoader(prediction_data, sampler=prediction_sampler, batch_size=batch_size)
# Out:
# WARNING:pytorch_pretrained_bert.tokenization:Token indices sequence length is longer than the specified maximum  sequence length for this BERT model (578 > 512). Running this sequence through BERT will result in indexing errors
# WARNING:pytorch_pretrained_bert.tokenization:Token indices sequence length is longer than the specified maximum  sequence length for this BERT model (518 > 512). Running this sequence through BERT will result in indexing errors
# WARNING:pytorch_pretrained_bert.tokenization:Token indices sequence length is longer than the specified maximum  sequence length for this BERT model (574 > 512). Running this sequence through BERT will result in indexing errors
# WARNING:pytorch_pretrained_bert.tokenization:Token indices sequence length is longer than the specified maximum  sequence length for this BERT model (578 > 512). Running this sequence through BERT will result in indexing errors
# WARNING:pytorch_pretrained_bert.tokenization:Token indices sequence length is longer than the specified maximum  sequence length for this BERT model (518 > 512). Running this sequence through BERT will result in indexing errors
# WARNING:pytorch_pretrained_bert.tokenization:Token indices sequence length is longer than the specified maximum  sequence length for this BERT model (574 > 512). Running this sequence through BERT will result in indexing errors

# %%
# Prediction on test set

# Put model in evaluation mode
model.eval()

# Tracking variables
predictions , true_labels = [], []

# Predict
for batch in prediction_dataloader:
  # Add batch to GPU
  batch = tuple(t.to(device) for t in batch)
  # Unpack the inputs from our dataloader
  b_input_ids, b_input_mask, b_labels = batch
  # Telling the model not to compute or store gradients, saving memory and speeding up prediction
  with torch.no_grad():
    # Forward pass, calculate logit predictions
    logits = model(b_input_ids, token_type_ids=None, attention_mask=b_input_mask)

  # Move logits and labels to CPU
  logits = logits.detach().cpu().numpy()
  label_ids = b_labels.to('cpu').numpy()

  # Store predictions and true labels
  predictions.append(logits)
  true_labels.append(label_ids)

# %%
# Import and evaluate each test batch using Matthew's correlation coefficient
from sklearn.metrics import matthews_corrcoef
matthews_set = []

for i in range(len(true_labels)):
  matthews = matthews_corrcoef(true_labels[i],
                 np.argmax(predictions[i], axis=1).flatten())
  matthews_set.append(matthews)

# %% [markdown]
# The final score will be based on the entire test set, but let's take a look at the scores on the individual batches to get a sense of the variability in the metric between batches.

# %%
matthews_set
# Out:
# [np.float64(0.7446875933994077),
#  np.float64(0.6667228946148682),
#  np.float64(0.9347826086956522),
#  np.float64(0.8078679646823672),
#  np.float64(0.8690039187664382),
#  np.float64(0.8661059519775998),
#  np.float64(0.688702486224654),
#  np.float64(0.935931622058421),
#  np.float64(0.6724954949247813),
#  np.float64(0.7347826086956522),
#  np.float64(0.9342105263157895),
#  np.float64(0.8053412701479471),
#  np.float64(0.8035011108192193),
#  np.float64(0.735689958019051),
#  np.float64(0.8008849557522124),
#  np.float64(0.8050847457627118),
#  np.float64(0.9347826086956522),
#  np.float64(0.7403221751892368),
#  np.float64(0.8111662691337524),
#  np.float64(0.9353448275862069),
#  np.float64(0.7343534474570096),
#  np.float64(0.8695980950674562),
#  np.float64(0.8695652173913043),
#  np.float64(0.8739460855427935),
#  np.float64(0.8035011108192193),
#  np.float64(0.8077218108175414),
#  np.float64(0.8679172077468597),
#  np.float64(0.7489247664799692),
#  np.float64(0.8678498307170841),
#  np.float64(0.8052627168725032),
#  np.float64(1.0),
#  np.float64(0.8733707726295862),
#  np.float64(0.8085179585479284),
#  np.float64(0.8701380234825076),
#  np.float64(0.467571900119518),
#  np.float64(0.7345420376074683),
#  np.float64(0.7324561403508771),
#  np.float64(0.811965811965812),
#  np.float64(0.6753310032998566),
#  np.float64(0.933342551576896),
#  np.float64(1.0),
#  np.float64(0.5497887014043704),
#  np.float64(0.6140587130857955),
#  np.float64(0.8695652173913043),
#  np.float64(0.8000079013516251),
#  np.float64(0.7402666766940736),
#  np.float64(0.7340685346907118),
#  np.float64(0.8070175438596491),
#  np.float64(0.8684544656499107),
#  np.float64(0.8701380234825076),
#  np.float64(0.9358974358974359),
#  np.float64(0.9356309347680319),
#  np.float64(0.6666732511263543),
#  np.float64(0.5565217391304348),
#  np.float64(0.7425350926780254),
#  np.float64(0.6666666666666666),
#  np.float64(0.9334163073596636),
#  np.float64(0.7510798788275486),
#  np.float64(0.7445006161989198),
#  np.float64(0.7424961087838052),
#  np.float64(0.8068743841118808),
#  np.float64(0.9342464706233888),
#  np.float64(0.6115306862454085)]

# %%
# Flatten the predictions and true values for aggregate Matthew's evaluation on the whole dataset
flat_predictions = [item for sublist in predictions for item in sublist]
flat_predictions = np.argmax(flat_predictions, axis=1).flatten()
flat_true_labels = [item for sublist in true_labels for item in sublist]

# %%
matthews_corrcoef(flat_true_labels, flat_predictions)
# Out:
# np.float64(0.7983983783135264)

# %% [markdown]
# Cool! In about half an hour and without doing any hyperparameter tuning (adjusting the learning rate, epochs, batch size, ADAM properties, etc.) we are able to get a good score. I should also mention we didn't train on the entire training dataset, but set aside a portion of it as our validation set for legibililty of code.
#
# If you look at the leaderboard [here](https://gluebenchmark.com/leaderboard/submission/zlssuBTm5XRs0aSKbFYGVIVdvbj1/-LhijX9VVmvJcvzKymxy), you'll see that our score (54) using the small version of BERT actually slightly outperforms the BERT authors' CoLA score (52) with the same model. If you wanted to tune the hyperparameters, use the entire train set, or use the larger BERT model instead you're likely able to push that score up higher into the mid- 60s, which looks like the state of the art as of July 2019!

# %% [markdown]
# ## Conclusion

# %% [markdown]
# This post demonstrate that with a pre-trained BERT model you can quickly and effectively create a high quality model with minimal effort and training time using the pytorch interface, regardless of the specific NLP task you are interested in.
